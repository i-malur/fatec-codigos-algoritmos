# %% [markdown]
# O modelo P4 foi criado para representar as 4 (quatro) partes de um algoritmo.
# 1	DECLARAÇÃO DE VARIÁVEIS: Aqui você irá criar variáveis de leitura, de saída e constantes, com seus valores iniciais conforme a parte 1 do quadro resumo;
# 2	LEITURA/ENTRADA DE DADOS: Aqui você solicita ao usuário a digitação/entrada das variáveis de leitura;
# 3	PROCESSAMENTO: Aqui você deverá efetuar os cálculos/fórmulas, se haver mais de uma elas deverão estar na ordem certa de cada cálculo, lembrando que poderá haver outros processos além das fórmulas como comparações lógicas por exemplo.
# 4	SAÍDA DE DADOS: Nesta parte final do programa, simplesmente deverão ser exibidas as variáveis de saída, isto é, de resultado de todos os cálculos para visualização do usuário em vídeo ou impressora.

# %% [markdown]
# # Exercício - Área do círculo

# %% [markdown]
# ## Fluxograma
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pseudocódigo
# ````
# // Algoritmo para calcular a área de um círculo
# variaveis
#     real RAIO
#     real AREA
#     constante PI = 3.14
#
# inicio
#     // 1. Inicialização das Variáveis
#     RAIO <- 0
#     AREA <- 0
#
#     // 2. Leitura do Valor do Raio
#     escreva("Digite o valor do raio: ")
#     leia(RAIO)
#
#     // 3. Cálculo da Área
#     AREA <- RAIO * RAIO * PI
#
#     // 4. Exibição do Resultado
#     escreva("A área do círculo com raio ", RAIO, " é: ", AREA)
# fimalgoritmo
# ````

# %% [markdown]
# ## Código em python

# %%
# declaração de variáveis
PI = 3.14
raio = 0
area = 0

raio = float(input("Digite o valor do raio: ")) # entrada de dados
area = raio * raio * PI # processamento
print(f"A área do círculo com raio {raio} é: {area}") # saída de dados
# Out:
# Digite o valor do raio: 2.5
# A área do círculo com raio 2.5 é: 19.625

# %%
# Código - Script 01
import os
import time

area = 0
raio = 0
pi = 3.14

raio = input('Digite o valor do raio: ')
area = (float(raio) ** 2) * pi

os.system("clear")  # use "cls" no Windows
print('\n')
print(f'A área será: {area:.3f}')
time.sleep(5)
# Out:
# Digite o valor do raio: 2.5
#
#
# A área será: 19.625

# %% [markdown]
# ### Script 01
#
# ```
# import os
# import time
# import sys
#
#
# area = 0
# raio = 0
# pi = 3.14
#
# raio = input('Digite o valor do raio: ')
#
# area = (float(raio) ** 2) * pi
# os.system("clear")
#
# print('\n')
# print(f'A área será: {area:.3f}')
#
# time.sleep(5)
# sys.exit()
# ```

# %% [markdown]
# # Exercício - Média de notas

# %% [markdown]
# ## Fluxograma
#
# ![p1.png](data:image/png;base64,...)

# %% [markdown]
# ## Pseudocódigo
#
# ```
# Algoritmo "CalculoMedia"
#
#     // Declaração de variáveis
#     Real NOTA1, NOTA2, MEDIA
#
#     // Entrada de dados
#     Escreva("Digite Nota1: ")
#     Leia(NOTA1)
#     Escreva("Digite Nota2: ")
#     Leia(NOTA2)
#
#     // Cálculo da média
#     MEDIA ← (NOTA1 + NOTA2) / 2
#
#     // Exibindo resultado
#     Escreva("A média é: ", MEDIA)
#
#     // Pausa de 5 segundos
#     Atraso(5000)
#
# FimAlgoritmo
# ```

# %% [markdown]
# ## Código em pyhton

# %%
# Código - Script 02

# -*- coding: utf-8 -*-

import os
import time

NOTA1 = 0
NOTA2 = 0
MEDIA = 0

NOTA1 = float(input('Digite Nota1: '))
NOTA2 = float(input('Digite Nota2: '))

MEDIA = (NOTA1 + NOTA2) / 2
print('\nA média é:', MEDIA)
time.sleep(5)
# Out:
# Digite Nota1: 10
# Digite Nota2: 7
#
# A média é: 8.5

# %% [markdown]
# Script 02
#
# ```
# # Configura o idioma em Português
# # -*- coding: utf-8 -*-
# import sys
# import time
#
# NOTA1 = 0
# NOTA2 = 0
# MEDIA = 0
#
# NOTA1 = float(input('Digite Nota1: '))
# NOTA2 = float(input('Digite Nota2: '))
#
# MEDIA = (NOTA1 + NOTA2) / 2
#
# print('\nA média é:', MEDIA)
# time.sleep(5)
# sys.exit()
# ```

# %% [markdown]
# # Exercício - cálculo de PI

# %% [markdown]
# ## Fluxograma
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Pseudocódigo
#
# ```
# Algoritmo "CalculoResultado"
#
#     // Declaração de variáveis
#     Real pi, resultado
#
#     // Inicialização das variáveis
#     pi ← 3.14
#     resultado ← 0
#
#     // Cálculos
#     resultado ← 10 * pi
#
#     // Exibindo resultados na tela
#     Escreva("O resultado é: ", resultado)
#     Escreva("\n")  // Pula uma linha
#
#     // Pausa de 5 segundos
#     Atraso(5000)
#
# FimAlgoritmo
# ```

# %% [markdown]
# ## Código em python

# %%
# -*- coding: utf-8 -*-


import os
import sys
import time

pi = 3.14
resultado = 0

resultado = 10 * pi

print('O resultado é:', resultado)
print('\n')

time.sleep(5)
# Out:
# O resultado é: 31.400000000000002

# %% [markdown]
# ## Script 03
#
# ```
# # -*- coding: utf-8 -*-
#
# import os
# import sys
# import time
#
# os.system('clear')
#
# pi = 3.14
# resultado = 0
# resultado = 10 * pi
#
# print('O resultado é:', resultado)
# print('\n')  # Pula uma linha
#
#
# time.sleep(5)
#
# # sys.exit()
#
# ```
